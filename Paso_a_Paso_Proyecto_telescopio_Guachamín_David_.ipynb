# %% [markdown]
# # TELESCOPIO JAMES WEBB
# ## Realizado por: David Guachamín

# %%
import matplotlib.pyplot as plt

# Función para graficar los puntos y verificar la condición
def graficar_cuadrado_y_verificar(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir B en puntos del eje x
    punto_izquierdo = (0, 0)
    punto_derecho = (B, 0)

    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Definir puntos del cuadrado
    punto_superior_izquierdo = (0, D)
    punto_superior_derecho = (B, D)

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Verificar si el punto (Px, Py) está dentro del cuadrado
    if 0 <= Px <= B and 0 <= Py <= D:
        print(f"El punto ({Px}, {Py}) está dentro del cuadrado. No es válido.")
    else:
        print(f"El punto ({Px}, {Py}) está fuera del cuadrado. Es válido.")

    # Graficar
    plt.figure(figsize=(8, 8))

    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")

    # Graficar los puntos
    plt.scatter(*punto_izquierdo, color="red", label="Punto Izquierdo (0,0)")
    plt.scatter(*punto_derecho, color="green", label=f"Punto Derecho ({B},0)")
    plt.scatter(*punto_foco, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")

    # Etiquetas y leyendas
    plt.title("Cuadrado y Puntos")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_verificar(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)
# Out:
# El punto (4, 6) está fuera del cuadrado. Es válido.

# %%
import matplotlib.pyplot as plt

# Función para graficar los puntos y verificar la condición
def graficar_cuadrado_y_verificar(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir B en puntos del eje x
    punto_izquierdo = (0, 0)
    punto_derecho = (B, 0)

    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Definir puntos del cuadrado
    punto_superior_izquierdo = (0, D)
    punto_superior_derecho = (B, D)

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Verificar si el punto (Px, Py) está dentro del cuadrado
    if 0 <= Px <= B and 0 <= Py <= D:
        print(f"El punto ({Px}, {Py}) está dentro del cuadrado. No es válido.")
    else:
        print(f"El punto ({Px}, {Py}) está fuera del cuadrado. Es válido.")

    # Graficar
    plt.figure(figsize=(8, 8))

    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")

    # Graficar los puntos
    plt.scatter(*punto_izquierdo, color="red", label="Punto Izquierdo (0,0)")
    plt.scatter(*punto_derecho, color="green", label=f"Punto Derecho ({B},0)")
    plt.scatter(*punto_foco, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")

    # Agregar nombres y coordenadas a los puntos
    plt.text(0, 0, "(0,0)", fontsize=9, color="red", ha='right')
    plt.text(B, 0, f"({B},0)", fontsize=9, color="green", ha='left')
    plt.text(F, 0, f"({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(0, D, f"(0,{D})", fontsize=9, color="blue", ha='right', va='bottom')
    plt.text(B, D, f"({B},{D})", fontsize=9, color="blue", ha='left', va='bottom')
    plt.text(Px, Py, f"({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Puntos")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_verificar(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)
# Out:
# El punto (4, 6) está fuera del cuadrado. Es válido.

# %%
import math

def recta_con_longitud(x1, y1, m, longitud):
    # Calcular la dirección del vector unitario
    dx = math.sqrt(longitud**2 / (1 + m**2))
    dy = m * dx
    
    # Punto final (positivo y negativo para ambas direcciones)
    x2_1, y2_1 = x1 + dx, y1 + dy  # Dirección positiva
    x2_2, y2_2 = x1 - dx, y1 - dy  # Dirección negativa
    
    # Ecuación de la recta usando punto-pendiente
    b = y1 - m * x1
    ecuacion = f"y = {m}x + {b}"
    
    # Resultados
    return {
        "ecuacion": ecuacion,
        "puntos": [(x1, y1), (x2_1, y2_1), (x2_2, y2_2)]
    }

# Ejemplo
x1, y1 = 2, 3  # Punto inicial
m = 0.5         # Pendiente
longitud = 10   # Longitud de la recta

resultado = recta_con_longitud(x1, y1, m, longitud)

# Mostrar resultados
print(f"Ecuación de la recta: {resultado['ecuacion']}")
print(f"Puntos delimitados por la longitud:")
for punto in resultado["puntos"]:
    print(f"{punto}")
# Out:
# Ecuación de la recta: y = 0.5x + 2.0
# Puntos delimitados por la longitud:
# (2, 3)
# (10.94427190999916, 7.47213595499958)
# (-6.944271909999159, -1.4721359549995796)

# %%
import matplotlib.pyplot as plt

# Función para calcular la ecuación de la recta y la recta perpendicular
def ecuacion_recta_y_perpendicular(p1, p2):
    # Coordenadas de los puntos
    x1, y1 = p1
    x2, y2 = p2

    # Calculamos la pendiente
    m1 = (y2 - y1) / (x2 - x1)

    # Intercepto b usando la forma y = mx + b
    b = y1 - m1 * x1  # Intercepto de la recta principal

    # Ecuación de la recta principal
    ecuacion_principal = f"y = {m1}x + {b}"

    # Calculamos la pendiente de la recta perpendicular
    if m1 != 0:
        m2 = -1 / m1  # Pendiente perpendicular
    else:
        m2 = None  # Recta horizontal, perpendicular será vertical

    # Resultado
    resultado = {
        "pendiente_principal": m1,
        "ecuacion_principal": ecuacion_principal,
        "pendiente_perpendicular": m2,
    }

    return resultado

def ecuacion_recta_perpendicular(p1, p2, punto_P):
    # Coordenadas de los puntos iniciales
    x1, y1 = p1
    x2, y2 = p2

    # Calculamos la pendiente de la recta original
    m1 = (y2 - y1) / (x2 - x1)

    # Calculamos la pendiente de la recta perpendicular
    if m1 != 0:
        m2 = -1 / m1
    else:
        raise ValueError("La recta original es horizontal, su perpendicular será vertical.")

    # Coordenadas del punto P
    x0, y0 = punto_P

    # Usamos la fórmula punto-pendiente para la recta perpendicular
    # y - y0 = m2 * (x - x0)
    b_perpendicular = y0 - m2 * x0  # Intercepto de la recta perpendicular
    ecuacion_perpendicular = f"y = {m2}x + {b_perpendicular}"

    return {
        "pendiente_perpendicular": m2,
        "ecuacion_perpendicular": ecuacion_perpendicular
    }

# Función para graficar los puntos y verificar la condición
def graficar_cuadrado_y_verificar(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir B en puntos del eje x
    punto_izquierdo = (0, 0)
    punto_derecho = (B, 0)

    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Definir puntos del cuadrado
    punto_superior_izquierdo = (0, D)
    punto_superior_derecho = (B, D)

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Verificar si el punto (Px, Py) está dentro del cuadrado
    if 0 <= Px <= B and 0 <= Py <= D:
        print(f"El punto ({Px}, {Py}) está dentro del cuadrado. No es válido.")
    else:
        print(f"El punto ({Px}, {Py}) está fuera del cuadrado. Es válido.")

    # Graficar
    plt.figure(figsize=(10, 10))

    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")

    # Graficar los puntos
    plt.scatter(*punto_izquierdo, color="red", label="Punto Izquierdo (0,0)")
    plt.scatter(*punto_derecho, color="green", label=f"Punto Derecho ({B},0)")
    plt.scatter(*punto_foco, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")

    # Agregar nombres y coordenadas a los puntos
    plt.text(0, 0, "(0,0)", fontsize=9, color="red", ha='right')
    plt.text(B, 0, f"({B},0)", fontsize=9, color="green", ha='left')
    plt.text(F, 0, f"({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(0, D, f"(0,{D})", fontsize=9, color="blue", ha='right', va='bottom')
    plt.text(B, D, f"({B},{D})", fontsize=9, color="blue", ha='left', va='bottom')
    plt.text(Px, Py, f"({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')

    # Graficar la recta perpendicular
    resultado_perpendicular = ecuacion_recta_perpendicular(p1, p2, (Px, Py))
    m_perpendicular = resultado_perpendicular["pendiente_perpendicular"]
    b_perpendicular = (Py - m_perpendicular * Px)
    x_values = range(min(0, B) - 5, max(0, B) + 5)
    y_values_perpendicular = [m_perpendicular * x + b_perpendicular for x in x_values]
    plt.plot(x_values, y_values_perpendicular, label=f"Recta Perpendicular: {resultado_perpendicular['ecuacion_perpendicular']}", color="red")

    # Etiquetas y leyendas
    plt.title("Cuadrado y Puntos con Recta Perpendicular")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso de las funciones
p1 = (4, 0)
p2 = (7, 8)
punto_P = (5, 4)  # Punto P por el que pasa la perpendicular

# Cálculo de la ecuación de la recta principal y perpendicular
resultado_recta = ecuacion_recta_y_perpendicular(p1, p2)
print(f"Pendiente de la recta principal: {resultado_recta['pendiente_principal']}")
print(f"Ecuación de la recta principal: {resultado_recta['ecuacion_principal']}")
if resultado_recta["pendiente_perpendicular"] is not None:
    print(f"Pendiente de la recta perpendicular: {resultado_recta['pendiente_perpendicular']}")
else:
    print("La pendiente de la recta perpendicular es indefinida (es vertical).")

resultado_perpendicular = ecuacion_recta_perpendicular(p1, p2, punto_P)
print(f"Pendiente de la recta perpendicular: {resultado_perpendicular['pendiente_perpendicular']}")
print(f"Ecuación de la recta perpendicular: {resultado_perpendicular['ecuacion_perpendicular']}")

# Graficar cuadrado y la recta perpendicular
graficar_cuadrado_y_verificar(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)
# Out:
# Pendiente de la recta principal: 2.6666666666666665
# Ecuación de la recta principal: y = 2.6666666666666665x + -10.666666666666666
# Pendiente de la recta perpendicular: -0.375
# Pendiente de la recta perpendicular: -0.375
# Ecuación de la recta perpendicular: y = -0.375x + 5.875
# El punto (4, 6) está fuera del cuadrado. Es válido.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    
    # Calcular el intercepto
    b = y1 - m * x1
    
    return m, b

# Función para graficar la recta y los puntos
def graficar_cuadrado_y_recta(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir B en puntos del eje x
    punto_izquierdo = (0, 0)
    punto_derecho = (B, 0)

    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Definir puntos del cuadrado
    punto_superior_izquierdo = (0, D)
    punto_superior_derecho = (B, D)

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m, b = ecuacion_recta((Px, Py), (F, 0))
    
    # Definir los valores de x para graficar la recta
    x_vals = np.linspace(min(Px, F) - 5, max(Px, F) + 5, 500)
    y_vals_recta = m * x_vals + b

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos
    plt.scatter(*punto_izquierdo, color="red", label="Punto Izquierdo (0,0)")
    plt.scatter(*punto_derecho, color="green", label=f"Punto Derecho ({B},0)")
    plt.scatter(*punto_foco, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")

    # Graficar la recta que pasa por P y F
    plt.plot(x_vals, y_vals_recta, label=f"Recta: y = {m:.2f}x + {b:.2f}", color="black")
    
    # Agregar nombres y coordenadas a los puntos
    plt.text(0, 0, "(0,0)", fontsize=9, color="red", ha='right')
    plt.text(B, 0, f"({B},0)", fontsize=9, color="green", ha='left')
    plt.text(F, 0, f"({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(Px, Py, f"({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Recta P-F")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_recta(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    
    # Calcular el intercepto
    b = y1 - m * x1
    
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    
    # Calcular la pendiente de la recta perpendicular
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal

    # Calcular el intercepto de la recta perpendicular
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular  # La recta perpendicular es vertical

# Función para graficar la recta y los puntos
def graficar_cuadrado_y_recta_perpendicular(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir B en puntos del eje x
    punto_izquierdo = (0, 0)
    punto_derecho = (B, 0)

    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Definir puntos del cuadrado
    punto_superior_izquierdo = (0, D)
    punto_superior_derecho = (B, D)

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Calcular la ecuación de la recta perpendicular que pasa por P
    m_perpendicular, b_perpendicular = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Definir los valores de x para graficar la recta original y la perpendicular
    x_vals = np.linspace(min(Px, F) - 5, max(Px, F) + 5, 500)
    y_vals_original = m_original * x_vals + b_original

    x_vals_perpendicular = np.linspace(Px - 5, Px + 5, 500)
    if m_perpendicular is not None:
        y_vals_perpendicular = m_perpendicular * x_vals_perpendicular + b_perpendicular
    else:
        # La recta perpendicular es vertical (x = constante)
        x_vals_perpendicular = [Px] * 500
        y_vals_perpendicular = np.linspace(min(0, D) - 5, max(0, D) + 5, 500)

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos
    plt.scatter(*punto_izquierdo, color="red", label="Punto Izquierdo (0,0)")
    plt.scatter(*punto_derecho, color="green", label=f"Punto Derecho ({B},0)")
    plt.scatter(*punto_foco, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")

    # Graficar la recta original (P-F)
    plt.plot(x_vals, y_vals_original, label=f"Recta P-F: y = {m_original:.2f}x + {b_original:.2f}", color="black")

    # Graficar la recta perpendicular
    if m_perpendicular is not None:
        plt.plot(x_vals_perpendicular, y_vals_perpendicular, label=f"Recta Perpendicular: y = {m_perpendicular:.2f}x + {b_perpendicular:.2f}", color="red")
    else:
        plt.axvline(x=Px, color="red", linestyle="--", label="Recta Perpendicular (Vertical)")

    # Agregar nombres y coordenadas a los puntos
    plt.text(0, 0, "(0,0)", fontsize=9, color="red", ha='right')
    plt.text(B, 0, f"({B},0)", fontsize=9, color="green", ha='left')
    plt.text(F, 0, f"({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(Px, Py, f"({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Rectas P-F y Perpendicular")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_recta_perpendicular(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    
    # Calcular el intercepto
    b = y1 - m * x1
    
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    
    # Calcular la pendiente de la recta perpendicular
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal

    # Calcular el intercepto de la recta perpendicular
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular  # La recta perpendicular es vertical

# Función para graficar la recta y los puntos
def graficar_cuadrado_y_recta_perpendicular(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir B en puntos del eje x
    punto_izquierdo = (0, 0)
    punto_derecho = (B, 0)

    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Definir puntos del cuadrado
    punto_superior_izquierdo = (0, D)
    punto_superior_derecho = (B, D)

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Calcular la ecuación de la recta perpendicular que pasa por P
    m_perpendicular, b_perpendicular = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Definir los valores de x para graficar la recta original limitada entre P y F
    x_vals_original = np.linspace(Px, F, 500)
    y_vals_original = m_original * x_vals_original + b_original

    # Definir los valores de x para graficar la recta perpendicular
    x_vals_perpendicular = np.linspace(Px - 5, Px + 5, 500)
    if m_perpendicular is not None:
        y_vals_perpendicular = m_perpendicular * x_vals_perpendicular + b_perpendicular
    else:
        # La recta perpendicular es vertical (x = constante)
        x_vals_perpendicular = [Px] * 500
        y_vals_perpendicular = np.linspace(min(0, D) - 5, max(0, D) + 5, 500)

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos
    plt.scatter(*punto_izquierdo, color="red", label="Punto Izquierdo (0,0)")
    plt.scatter(*punto_derecho, color="green", label=f"Punto Derecho ({B},0)")
    plt.scatter(*punto_foco, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")

    # Graficar la recta original (P-F)
    plt.plot(x_vals_original, y_vals_original, label=f"Recta P-F: y = {m_original:.2f}x + {b_original:.2f}", color="black")

    # Graficar la recta perpendicular
    if m_perpendicular is not None:
        plt.plot(x_vals_perpendicular, y_vals_perpendicular, label=f"Recta Perpendicular: y = {m_perpendicular:.2f}x + {b_perpendicular:.2f}", color="red")
    else:
        plt.axvline(x=Px, color="red", linestyle="--", label="Recta Perpendicular (Vertical)")

    # Agregar nombres y coordenadas a los puntos
    plt.text(0, 0, "(0,0)", fontsize=9, color="red", ha='right')
    plt.text(B, 0, f"({B},0)", fontsize=9, color="green", ha='left')
    plt.text(F, 0, f"({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(Px, Py, f"({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Rectas P-F y Perpendicular")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_recta_perpendicular(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    
    # Calcular el intercepto
    b = y1 - m * x1
    
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    
    # Calcular la pendiente de la recta perpendicular
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal

    # Calcular el intercepto de la recta perpendicular
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular  # La recta perpendicular es vertical

# Función para graficar el cuadrado, las rectas y los puntos
def graficar_cuadrado_y_recta_perpendicular(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Calcular la ecuación de la recta perpendicular que pasa por P
    m_perpendicular, b_perpendicular = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Calcular la longitud de la recta perpendicular desde P hacia ambos lados
    if m_perpendicular is not None:
        # Calcular la longitud total de la mitad de la recta (distancia desde P a cada extremo)
        d = L / 2 / np.sqrt(1 + m_perpendicular**2)

        # Calcular los puntos extremos de la recta perpendicular
        x1 = Px - d
        y1 = m_perpendicular * x1 + b_perpendicular
        R = (x1, y1)

        x2 = Px + d
        y2 = m_perpendicular * x2 + b_perpendicular
        T = (x2, y2)
    else:
        # La recta perpendicular es vertical (x = constante)
        x1 = Px
        y1 = Py - L / 2
        R = (x1, y1)

        x2 = Px
        y2 = Py + L / 2
        T = (x2, y2)

    # Definir los valores de x para graficar la recta original limitada entre P y F
    x_vals_original = np.linspace(Px, F, 500)
    y_vals_original = m_original * x_vals_original + b_original

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"Punto P ({Px},{Py})")
    plt.scatter(*R, color="red", label=f"Punto R ({R[0]:.2f},{R[1]:.2f})")
    plt.scatter(*T, color="green", label=f"Punto T ({T[0]:.2f},{T[1]:.2f})")

    # Graficar la recta original (P-F)
    plt.plot(x_vals_original, y_vals_original, label=f"Recta P-F: y = {m_original:.2f}x + {b_original:.2f}", color="black")

    # Graficar la recta perpendicular con longitud L
    plt.plot([R[0], T[0]], [R[1], T[1]], label=f"Recta Perpendicular con L={L}", color="red")

    # Agregar nombres y coordenadas a los puntos
    plt.text(F, 0, f"F ({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(Px, Py, f"P ({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')
    plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=9, color="red", ha='right', va='top')
    plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=9, color="green", ha='left', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Rectas P-F y Perpendicular con Longitud L")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_recta_perpendicular(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    
    # Calcular el intercepto
    b = y1 - m * x1
    
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    
    # Calcular la pendiente de la recta perpendicular
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal

    # Calcular el intercepto de la recta perpendicular
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular  # La recta perpendicular es vertical

# Función para graficar el cuadrado, las rectas y los puntos
def graficar_cuadrado_y_recta_perpendicular(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Calcular la ecuación de la recta perpendicular que pasa por P
    m_perpendicular, b_perpendicular = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Calcular la longitud de la recta perpendicular desde P hacia ambos lados
    if m_perpendicular is not None:
        # Calcular la longitud total de la mitad de la recta (distancia desde P a cada extremo)
        d = L / 2 / np.sqrt(1 + m_perpendicular**2)

        # Calcular los puntos extremos de la recta perpendicular
        x1 = Px - d
        y1 = m_perpendicular * x1 + b_perpendicular
        R = (x1, y1)

        x2 = Px + d
        y2 = m_perpendicular * x2 + b_perpendicular
        T = (x2, y2)
    else:
        # La recta perpendicular es vertical (x = constante)
        x1 = Px
        y1 = Py - L / 2
        R = (x1, y1)

        x2 = Px
        y2 = Py + L / 2
        T = (x2, y2)

    # Definir los valores de x para graficar la recta original limitada entre P y F
    x_vals_original = np.linspace(Px, F, 500)
    y_vals_original = m_original * x_vals_original + b_original

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(*R, color="red", label=f"Punto R ({R[0]:.2f},{R[1]:.2f})")
    plt.scatter(*T, color="green", label=f"Punto T ({T[0]:.2f},{T[1]:.2f})")
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")

    # Graficar la recta original (P-F)
    plt.plot(x_vals_original, y_vals_original, label=f"Recta P-F: y = {m_original:.2f}x + {b_original:.2f}", color="black")

    # Graficar la recta perpendicular con longitud L
    plt.plot([R[0], T[0]], [R[1], T[1]], label=f"Recta Perpendicular con L={L}", color="red")

    # Agregar nombres y coordenadas a los puntos
    plt.text(F, 0, f"F ({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(Px, Py, f"P ({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')
    plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=9, color="red", ha='right', va='top')
    plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=9, color="green", ha='left', va='bottom')
    plt.text(0, 0, "A (0,0)", fontsize=9, color="black", ha='right', va='bottom')
    plt.text(B, 0, f"B ({B},0)", fontsize=9, color="blue", ha='left', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Rectas P-F y Perpendicular con Longitud L")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_cuadrado_y_recta_perpendicular(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt

# Función para graficar los trapecios con anotaciones
def graficar_trapecios_anotados(L, B, Dmin, Dmax):
    # Alturas de los trapecios
    altura1 = Dmin + Dmax
    altura2 = Dmin

    # Coordenadas del primer trapecio (Base menor: L, Base mayor: B, Altura: Dmin + Dmax)
    trapecio1_x = [0, (B - L) / 2, (B + L) / 2, B, 0]
    trapecio1_y = [0, altura1, altura1, 0, 0]

    # Coordenadas del segundo trapecio (Base menor: L, Base mayor: B, Altura: Dmin)
    trapecio2_x = [0, (B - L) / 2, (B + L) / 2, B, 0]
    trapecio2_y = [0, altura2, altura2, 0, 0]

    # Graficar
    plt.figure(figsize=(10, 10))
    
    # Primer trapecio
    plt.plot(trapecio1_x, trapecio1_y, label="Trapecio 1 (Dmin + Dmax)", color="blue")
    plt.fill(trapecio1_x, trapecio1_y, color="blue", alpha=0.2)

    # Segundo trapecio
    plt.plot(trapecio2_x, trapecio2_y, label="Trapecio 2 (Dmin)", color="orange")
    plt.fill(trapecio2_x, trapecio2_y, color="orange", alpha=0.2)

    # Agregar alturas
    plt.plot([B/2, B/2], [0, altura1], color="blue", linestyle="--", label="Altura Trapecio 1")
    plt.text(B/2, altura1 / 2, f"Altura: {altura1}", fontsize=9, color="blue", ha='center', va='bottom')

    plt.plot([B/2, B/2], [0, altura2], color="orange", linestyle="--", label="Altura Trapecio 2")
    plt.text(B/2, altura2 / 2, f"Altura: {altura2}", fontsize=9, color="orange", ha='center', va='bottom')

    # Anotar las bases y los lados de los trapecios
    # Base mayor
    plt.text(B / 2, -0.5, f"Base mayor: {B}", fontsize=9, color="black", ha='center')
    
    # Base menor
    plt.text((B - L) / 2 + L / 2, altura1 + 0.2, f"Base menor: {L}", fontsize=9, color="blue", ha='center')
    plt.text((B - L) / 2 + L / 2, altura2 + 0.2, f"Base menor: {L}", fontsize=9, color="orange", ha='center')

    # Lados del primer trapecio
    lado1 = ((B - L) / 2)**2 + altura1**2
    lado1 = round(lado1**0.5, 2)
    plt.text((B - L) / 4, altura1 / 2, f"Lado: {lado1}", fontsize=9, color="blue", rotation=45)

    # Lados del segundo trapecio
    lado2 = ((B - L) / 2)**2 + altura2**2
    lado2 = round(lado2**0.5, 2)
    plt.text((B - L) / 4, altura2 / 2, f"Lado: {lado2}", fontsize=9, color="orange", rotation=45)

    # Configurar la gráfica
    plt.title("Trapecios Isósceles - Limitaciones")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_trapecios_anotados(L=5, B=10, Dmin=3, Dmax=2)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    
    # Calcular el intercepto
    b = y1 - m * x1
    
    return m, b

# Función para graficar el cuadrado, las rectas y los puntos
def graficar_puntos_sobre_recta(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 1
    distancia = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia) + 1
    puntos = [(Px + i * (F - Px) / distancia, Py + i * (0 - Py) / distancia) for i in range(num_puntos)]

    # Definir los valores de x para graficar la recta original limitada entre P y F
    x_vals_original = np.linspace(Px, F, 500)
    y_vals_original = m_original * x_vals_original + b_original

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")

    # Graficar la recta original (P-F)
    plt.plot(x_vals_original, y_vals_original, label=f"Recta P-F: y = {m_original:.2f}x + {b_original:.2f}", color="black")

    # Graficar los puntos generados sobre la recta P-F
    puntos_x, puntos_y = zip(*puntos)
    plt.scatter(puntos_x, puntos_y, color="red", label="Puntos sobre P-F (separación = 1)")

    # Agregar nombres y coordenadas a los puntos principales
    plt.text(F, 0, f"F ({F},0)", fontsize=9, color="purple", ha='center', va='bottom')
    plt.text(Px, Py, f"P ({Px},{Py})", fontsize=9, color="orange", ha='center', va='bottom')
    plt.text(0, 0, "A (0,0)", fontsize=9, color="black", ha='right', va='bottom')
    plt.text(B, 0, f"B ({B},0)", fontsize=9, color="blue", ha='left', va='bottom')

    # Etiquetas y leyendas
    plt.title("Cuadrado y Puntos sobre la Recta P-F")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_sobre_recta(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    
    # Calcular la pendiente de la recta perpendicular
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal

    # Calcular el intercepto de la recta perpendicular
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular  # La recta perpendicular es vertical

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia, Py + i * 0.5 * (0 - Py) / distancia) for i in range(num_puntos)]

    # Calcular la ecuación de la recta perpendicular que pasa por P
    m_perpendicular, b_perpendicular = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Calcular los extremos de la recta perpendicular (longitud = L, centrada en P)
    if m_perpendicular is not None:
        d = L / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = Px - d
        y1 = m_perpendicular * x1 + b_perpendicular
        R = (x1, y1)

        x2 = Px + d
        y2 = m_perpendicular * x2 + b_perpendicular
        T = (x2, y2)
    else:
        x1 = Px
        y1 = Py - L / 2
        R = (x1, y1)

        x2 = Px
        y2 = Py + L / 2
        T = (x2, y2)

    # Definir los valores de x para graficar la recta original limitada entre P y F
    x_vals_original = np.linspace(Px, F, 500)
    y_vals_original = m_original * x_vals_original + b_original

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")
    plt.scatter(*R, color="red", label=f"Punto R ({R[0]:.2f},{R[1]:.2f})")
    plt.scatter(*T, color="green", label=f"Punto T ({T[0]:.2f},{T[1]:.2f})")

    # Graficar la recta original (P-F)
    plt.plot(x_vals_original, y_vals_original, label=f"Recta P-F: y = {m_original:.2f}x + {b_original:.2f}", color="black")

    # Graficar los puntos generados sobre la recta P-F
    puntos_x, puntos_y = zip(*puntos)
    plt.scatter(puntos_x, puntos_y, color="red", label="Puntos sobre P-F (separación = 0.5)", s=10)

    # Graficar la recta perpendicular con longitud L
    plt.plot([R[0], T[0]], [R[1], T[1]], label=f"Recta Perpendicular con L={L}", color="red")

    # Agregar etiquetas y leyendas
    plt.title("Cuadrado, Rectas P-F y Perpendicular, y Puntos sobre P-F")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    
    # Calcular la pendiente
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    
    # Calcular la pendiente de la recta perpendicular
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal

    # Calcular el intercepto de la recta perpendicular
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular  # La recta perpendicular es vertical

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia, Py + i * 0.5 * (0 - Py) / distancia) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")

    # Graficar los puntos generados sobre la recta P-F
    puntos_x, puntos_y = zip(*puntos)
    plt.scatter(puntos_x, puntos_y, color="red", label="Puntos sobre P-F (separación = 0.5)", s=10)

    # Graficar las rectas perpendiculares
    for punto in puntos:
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", alpha=0.7)

    # Agregar etiquetas y leyendas
    plt.title("Cuadrado, Rectas Perpendiculares a P-F y Puntos sobre P-F")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia, Py + i * 0.5 * (0 - Py) / distancia) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Graficar
    plt.figure(figsize=(8, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")

    # Graficar los puntos generados sobre la recta P-F
    puntos_x, puntos_y = zip(*puntos)
    plt.scatter(puntos_x, puntos_y, color="red", label="Puntos sobre P-F (separación = 0.5)", s=10)

    # Graficar las rectas perpendiculares y sus extremos
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", alpha=0.7, label="Rectas Perpendiculares" if i == 0 else "")
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R{i} ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T{i} ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

    # Agregar etiquetas y leyendas
    plt.title("Cuadrado, Rectas Perpendiculares a P-F y Puntos sobre P-F")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia, Py + i * 0.5 * (0 - Py) / distancia) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Graficar
    plt.figure(figsize=(10, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")

    # Graficar los puntos generados sobre la recta P-F
    puntos_x, puntos_y = zip(*puntos)
    plt.scatter(puntos_x, puntos_y, color="red", label="Puntos sobre P-F (separación = 0.5)", s=10)

    # Graficar las rectas perpendiculares y sus extremos
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", alpha=0.7, label="Rectas Perpendiculares" if i == 0 else "")
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R{i} ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T{i} ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

        # Unir extremos izquierdos al punto A
        plt.plot([R[0], 0], [R[1], 0], color="orange", linestyle="--", alpha=0.5, label="R-A" if i == 0 else "")

        # Unir extremos derechos al punto B
        plt.plot([T[0], B], [T[1], 0], color="brown", linestyle="--", alpha=0.5, label="T-B" if i == 0 else "")

    # Agregar etiquetas y leyendas
    plt.title("Cuadrado, Rectas Perpendiculares a P-F y Puntos sobre P-F")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para calcular la distancia entre dos puntos
def distancia(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia_total = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia_total / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia_total, Py + i * 0.5 * (0 - Py) / distancia_total) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Graficar
    plt.figure(figsize=(12, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")

    # Graficar las rectas perpendiculares y sus extremos si cumplen la condición
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        
        # Verificar las condiciones de distancia
        if Dmin <= distancia_RA <= Dmin + Dmax and Dmin <= distancia_TB <= Dmin + Dmax:
            # Graficar la recta perpendicular
            plt.plot([R[0], T[0]], [R[1], T[1]], color="green", alpha=0.7, label="Rectas Perpendiculares" if i == 0 else "")
            
            # Graficar extremos
            plt.scatter(*R, color="purple", s=20)
            plt.scatter(*T, color="purple", s=20)
            plt.text(R[0], R[1], f"R{i} ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
            plt.text(T[0], T[1], f"T{i} ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

            # Calcular y mostrar las distancias de R a A y T a B
            plt.text(R[0] / 2, R[1] / 2, f"{distancia_RA:.2f}", fontsize=8, color="red", va='center')
            plt.text((B + T[0]) / 2, (T[1]) / 2, f"{distancia_TB:.2f}", fontsize=8, color="brown", va='center')

            # Unir extremos izquierdos al punto A
            plt.plot([R[0], 0], [R[1], 0], color="orange", linestyle="--", alpha=0.5, label="R-A" if i == 0 else "")

            # Unir extremos derechos al punto B
            plt.plot([T[0], B], [T[1], 0], color="brown", linestyle="--", alpha=0.5, label="T-B" if i == 0 else "")

    # Agregar etiquetas y leyendas
    plt.title("Cuadrado, Rectas Perpendiculares Condicionales y Uniones")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para calcular la distancia entre dos puntos
def distancia(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia_total = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia_total / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia_total, Py + i * 0.5 * (0 - Py) / distancia_total) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Variables para almacenar la paralela con la mayor suma de longitudes
    max_longitud_suma = 0
    mejor_paralela = None
    mejor_R = None
    mejor_T = None

    # Graficar
    plt.figure(figsize=(12, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")

    # Graficar la recta P-F con línea entrecortada
    x_vals_PF = np.linspace(Px, F, 500)
    y_vals_PF = m_original * x_vals_PF + b_original
    plt.plot(x_vals_PF, y_vals_PF, 'k--', label="Recta P-F")

    # Iterar y encontrar la paralela con la mayor suma de longitudes
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        
        # Verificar las condiciones de distancia
        if Dmin <= distancia_RA <= Dmin + Dmax and Dmin <= distancia_TB <= Dmin + Dmax:
            suma_longitudes = distancia_RA + distancia_TB
            if suma_longitudes > max_longitud_suma:
                max_longitud_suma = suma_longitudes
                mejor_paralela = (R, T)
                mejor_R = R
                mejor_T = T

    # Graficar la mejor paralela encontrada
    if mejor_paralela:
        R, T = mejor_paralela
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", label="Mejor Paralela")

        # Graficar extremos
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

        # Calcular y mostrar las distancias de R a A y T a B
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        plt.text(R[0] / 2, R[1] / 2, f"{distancia_RA:.2f}", fontsize=8, color="red", va='center')
        plt.text((B + T[0]) / 2, (T[1]) / 2, f"{distancia_TB:.2f}", fontsize=8, color="brown", va='center')

        # Unir extremos izquierdos al punto A (línea sólida)
        plt.plot([R[0], 0], [R[1], 0], color="orange", label="R-A")

        # Unir extremos derechos al punto B (línea sólida)
        plt.plot([T[0], B], [T[1], 0], color="brown", label="T-B")

    # Agregar etiquetas y leyendas
    plt.title("TELESCOPIO JAMES WEBB")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=5, B=10, Dmin=3, Dmax=2, Px=4, Py=6, F=7)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para calcular la distancia entre dos puntos
def distancia(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia_total = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia_total / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia_total, Py + i * 0.5 * (0 - Py) / distancia_total) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Variables para almacenar la paralela con la mayor suma de longitudes
    max_longitud_suma = 0
    mejor_paralela = None
    mejor_R = None
    mejor_T = None

    # Graficar
    plt.figure(figsize=(12, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")

    # Graficar la recta P-F con línea entrecortada
    x_vals_PF = np.linspace(Px, F, 500)
    y_vals_PF = m_original * x_vals_PF + b_original
    plt.plot(x_vals_PF, y_vals_PF, 'k--', label="Recta P-F")

    # Iterar y encontrar la paralela con la mayor suma de longitudes
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        
        # Verificar las condiciones de distancia
        if Dmin <= distancia_RA <= Dmin + Dmax and Dmin <= distancia_TB <= Dmin + Dmax:
            suma_longitudes = distancia_RA + distancia_TB
            if suma_longitudes > max_longitud_suma:
                max_longitud_suma = suma_longitudes
                mejor_paralela = (R, T)
                mejor_R = R
                mejor_T = T

    # Graficar la mejor paralela encontrada
    if mejor_paralela:
        R, T = mejor_paralela
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", label="Mejor Paralela")

        # Graficar extremos
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

        # Calcular y mostrar las distancias de R a A y T a B
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        plt.text(R[0] / 2, R[1] / 2, f"{distancia_RA:.2f}", fontsize=8, color="red", va='center')
        plt.text((B + T[0]) / 2, (T[1]) / 2, f"{distancia_TB:.2f}", fontsize=8, color="brown", va='center')

        # Unir extremos izquierdos al punto A (línea sólida)
        plt.plot([R[0], 0], [R[1], 0], color="orange", label="R-A")

        # Unir extremos derechos al punto B (línea sólida)
        plt.plot([T[0], B], [T[1], 0], color="brown", label="T-B")

    # Agregar etiquetas y leyendas
    plt.title("TELESCOPIO JAMES WEBB")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=8, B=11, Dmin=7, Dmax=9, Px=18, Py=22, F=3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para calcular la distancia entre dos puntos
def distancia(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia_total = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia_total / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia_total, Py + i * 0.5 * (0 - Py) / distancia_total) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Variables para almacenar la paralela con la mayor suma de longitudes
    max_longitud_suma = 0
    mejor_paralela = None
    mejor_R = None
    mejor_T = None

    # Graficar
    plt.figure(figsize=(12, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")

    # Graficar la recta P-F con línea entrecortada
    x_vals_PF = np.linspace(Px, F, 500)
    y_vals_PF = m_original * x_vals_PF + b_original
    plt.plot(x_vals_PF, y_vals_PF, 'k--', label="Recta P-F")

    # Iterar y encontrar la paralela con la mayor suma de longitudes
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        
        # Verificar las condiciones de distancia
        if Dmin <= distancia_RA <= Dmin + Dmax and Dmin <= distancia_TB <= Dmin + Dmax:
            suma_longitudes = distancia_RA + distancia_TB
            if suma_longitudes > max_longitud_suma:
                max_longitud_suma = suma_longitudes
                mejor_paralela = (R, T)
                mejor_R = R
                mejor_T = T

    # Graficar la mejor paralela encontrada
    if mejor_paralela:
        R, T = mejor_paralela
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", label="Mejor Paralela")

        # Graficar extremos
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

        # Calcular y mostrar las distancias de R a A y T a B
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        plt.text(R[0] / 2, R[1] / 2, f"{distancia_RA:.2f}", fontsize=8, color="red", va='center')
        plt.text((B + T[0]) / 2, (T[1]) / 2, f"{distancia_TB:.2f}", fontsize=8, color="brown", va='center')

        # Unir extremos izquierdos al punto A (línea sólida)
        plt.plot([R[0], 0], [R[1], 0], color="orange", label="R-A")

        # Unir extremos derechos al punto B (línea sólida)
        plt.plot([T[0], B], [T[1], 0], color="brown", label="T-B")

    # Agregar etiquetas y leyendas
    plt.title("TELESCOPIO JAMES WEBB")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=20, B=12, Dmin=5, Dmax=3, Px=32, Py=57, F=9)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para calcular la distancia entre dos puntos
def distancia(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia_total = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia_total / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia_total, Py + i * 0.5 * (0 - Py) / distancia_total) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Variables para almacenar la paralela con la mayor suma de longitudes
    max_longitud_suma = 0
    mejor_paralela = None
    mejor_R = None
    mejor_T = None

    # Graficar
    plt.figure(figsize=(12, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")

    # Graficar la recta P-F con línea entrecortada
    x_vals_PF = np.linspace(Px, F, 500)
    y_vals_PF = m_original * x_vals_PF + b_original
    plt.plot(x_vals_PF, y_vals_PF, 'k--', label="Recta P-F")

    # Iterar y encontrar la paralela con la mayor suma de longitudes
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        
        # Verificar las condiciones de distancia
        if Dmin <= distancia_RA <= Dmin + Dmax and Dmin <= distancia_TB <= Dmin + Dmax:
            suma_longitudes = distancia_RA + distancia_TB
            if suma_longitudes > max_longitud_suma:
                max_longitud_suma = suma_longitudes
                mejor_paralela = (R, T)
                mejor_R = R
                mejor_T = T

    # Graficar la mejor paralela encontrada
    if mejor_paralela:
        R, T = mejor_paralela
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", label="Mejor Paralela")

        # Graficar extremos
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

        # Calcular y mostrar las distancias de R a A y T a B
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        plt.text(R[0] / 2, R[1] / 2, f"{distancia_RA:.2f}", fontsize=8, color="red", va='center')
        plt.text((B + T[0]) / 2, (T[1]) / 2, f"{distancia_TB:.2f}", fontsize=8, color="brown", va='center')

        # Anotaciones para X1 y X2 en las rectas R-A y T-B
        X1 = distancia_RA - Dmin
        X2 = distancia_TB - Dmin
        plt.text(R[0] / 2, R[1] / 2 + 0.5, f"X1 = {X1:.2f}", fontsize=10, color="blue")
        plt.text((B + T[0]) / 2, (T[1]) / 2 + 0.5, f"X2 = {X2:.2f}", fontsize=10, color="blue")

        # Unir extremos izquierdos al punto A (línea sólida)
        plt.plot([R[0], 0], [R[1], 0], color="orange", label="R-A")

        # Unir extremos derechos al punto B (línea sólida)
        plt.plot([T[0], B], [T[1], 0], color="brown", label="T-B")

    # Agregar etiquetas y leyendas
    plt.title("TELESCOPIO JAMES WEBB")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Ejemplo de uso
graficar_puntos_y_rectas(L=8, B=11, Dmin=7, Dmax=9, Px=18, Py=22, F=3)

# %% [markdown]
# ## CODIGO FINAL CON INTERFAZ GRAFICA

# %%
import matplotlib.pyplot as plt
import numpy as np
import tkinter as tk
from tkinter import simpledialog

# Función para calcular la ecuación de la recta que pasa por dos puntos
def ecuacion_recta(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    m = (y2 - y1) / (x2 - x1)
    b = y1 - m * x1
    return m, b

# Función para calcular la ecuación de la recta perpendicular que pasa por un punto
def ecuacion_recta_perpendicular(p1, m_original):
    x0, y0 = p1
    if m_original != 0:
        m_perpendicular = -1 / m_original
    else:
        m_perpendicular = None  # Caso especial: la recta original es horizontal
    if m_perpendicular is not None:
        b_perpendicular = y0 - m_perpendicular * x0
        return m_perpendicular, b_perpendicular
    else:
        return m_perpendicular

# Función para calcular los extremos de una recta perpendicular dada una longitud y un punto
def extremos_recta_perpendicular(punto, m_perpendicular, longitud):
    x0, y0 = punto
    if m_perpendicular is not None:
        d = longitud / 2 / np.sqrt(1 + m_perpendicular**2)
        x1 = x0 - d
        y1 = m_perpendicular * x1 + (y0 - m_perpendicular * x0)
        x2 = x0 + d
        y2 = m_perpendicular * x2 + (y0 - m_perpendicular * x0)
        return (x1, y1), (x2, y2)
    else:
        x1 = x0
        y1 = y0 - longitud / 2
        x2 = x0
        y2 = y0 + longitud / 2
        return (x1, y1), (x2, y2)

# Función para calcular la distancia entre dos puntos
def distancia(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# Función para graficar puntos y rectas
def graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F):
    # Convertir F en punto
    punto_foco = (F, 0)

    # Calcular D
    D = Dmin + Dmax

    # Crear la lista de vértices para graficar el cuadrado
    cuadrado_x = [0, 0, B, B, 0]
    cuadrado_y = [0, D, D, 0, 0]

    # Calcular la ecuación de la recta que pasa por P y F
    m_original, b_original = ecuacion_recta((Px, Py), (F, 0))

    # Generar puntos a lo largo de la recta P-F con una separación de 0.5
    distancia_total = np.sqrt((F - Px)**2 + (0 - Py)**2)
    num_puntos = int(distancia_total / 0.5) + 1
    puntos = [(Px + i * 0.5 * (F - Px) / distancia_total, Py + i * 0.5 * (0 - Py) / distancia_total) for i in range(num_puntos)]

    # Calcular la pendiente de la recta perpendicular
    m_perpendicular, _ = ecuacion_recta_perpendicular((Px, Py), m_original)

    # Variables para almacenar la paralela con la mayor suma de longitudes
    max_longitud_suma = 0
    mejor_paralela = None
    mejor_R = None
    mejor_T = None

    # Graficar
    plt.figure(figsize=(12, 8))
    
    # Graficar el cuadrado
    plt.plot(cuadrado_x, cuadrado_y, label="Cuadrado", color="blue")
    
    # Graficar los puntos principales
    plt.scatter(0, 0, color="black", label="A (0,0)")
    plt.scatter(B, 0, color="blue", label=f"B ({B},0)")
    plt.scatter(Px, Py, color="orange", label=f"P ({Px},{Py})")
    plt.scatter(F, 0, color="purple", label=f"F ({F},0)")

    # Graficar la recta P-F con línea entrecortada
    x_vals_PF = np.linspace(Px, F, 500)
    y_vals_PF = m_original * x_vals_PF + b_original
    plt.plot(x_vals_PF, y_vals_PF, 'k--', label="Recta P-F")

    # Iterar y encontrar la paralela con la mayor suma de longitudes
    for i, punto in enumerate(puntos):
        R, T = extremos_recta_perpendicular(punto, m_perpendicular, L)
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        
        # Verificar las condiciones de distancia
        if Dmin <= distancia_RA <= Dmin + Dmax and Dmin <= distancia_TB <= Dmin + Dmax:
            suma_longitudes = distancia_RA + distancia_TB
            if suma_longitudes > max_longitud_suma:
                max_longitud_suma = suma_longitudes
                mejor_paralela = (R, T)
                mejor_R = R
                mejor_T = T

    # Graficar la mejor paralela encontrada
    if mejor_paralela:
        R, T = mejor_paralela
        plt.plot([R[0], T[0]], [R[1], T[1]], color="green", label="Mejor Paralela")

        # Graficar extremos
        plt.scatter(*R, color="purple", s=20)
        plt.scatter(*T, color="purple", s=20)
        plt.text(R[0], R[1], f"R ({R[0]:.2f},{R[1]:.2f})", fontsize=8, color="purple", ha='right')
        plt.text(T[0], T[1], f"T ({T[0]:.2f},{T[1]:.2f})", fontsize=8, color="purple", ha='left')

        # Calcular y mostrar las distancias de R a A y T a B
        distancia_RA = distancia(R, (0, 0))
        distancia_TB = distancia(T, (B, 0))
        plt.text(R[0] / 2, R[1] / 2, f"{distancia_RA:.2f}", fontsize=8, color="red", va='center')
        plt.text((B + T[0]) / 2, (T[1]) / 2, f"{distancia_TB:.2f}", fontsize=8, color="brown", va='center')

        # Anotaciones para X1 y X2 en las rectas R-A y T-B
        X1 = distancia_RA - Dmin
        X2 = distancia_TB - Dmin
        plt.text(R[0] / 2, R[1] / 2 + 0.5, f"X1 = {X1:.2f}", fontsize=10, color="blue")
        plt.text((B + T[0]) / 2, (T[1]) / 2 + 0.5, f"X2 = {X2:.2f}", fontsize=10, color="blue")

        # Unir extremos izquierdos al punto A (línea sólida)
        plt.plot([R[0], 0], [R[1], 0], color="orange", label="R-A")

        # Unir extremos derechos al punto B (línea sólida)
        plt.plot([T[0], B], [T[1], 0], color="brown", label="T-B")

    # Agregar etiquetas y leyendas
    plt.title("TELESCOPIO JAMES WEBB")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

# Función para obtener los parámetros desde la interfaz gráfica
def obtener_parametros():
    root = tk.Tk()
    root.withdraw()  # Oculta la ventana principal

    L = simpledialog.askfloat("Input", "Ingrese L (ej. 8):")
    B = simpledialog.askfloat("Input", "Ingrese B (ej. 11):")
    Dmin = simpledialog.askfloat("Input", "Ingrese Dmin (ej. 7):")
    Dmax = simpledialog.askfloat("Input", "Ingrese Dmax (ej. 9):")
    Px = simpledialog.askfloat("Input", "Ingrese Px (ej. 18):")
    Py = simpledialog.askfloat("Input", "Ingrese Py (ej. 22):")
    F = simpledialog.askfloat("Input", "Ingrese F (ej. 3):")

    if None not in (L, B, Dmin, Dmax, Px, Py, F):
        graficar_puntos_y_rectas(L, B, Dmin, Dmax, Px, Py, F)

# Ejecutar la función para obtener los parámetros y graficar
if __name__ == "__main__":
    obtener_parametros()
